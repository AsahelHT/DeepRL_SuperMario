# %% [markdown]
# # 🕹️👾 Deep Reinforcement Learning aplicado a *Super Mario Bros* 👾🕹️
#
# ---
#
# ## Presentación de la práctica
#
# Se entrega un **notebook modificado** para facilitar la comprensión y ejecución de la práctica desarrollada.
# Este cuaderno ha sido adaptado eliminando las celdas de los tutoriales de ejemplo y añadiendo nuevas secciones para mejorar el flujo de trabajo y el entendimiento del código.
#
# 🚀 **[Explora el proyecto en GitHub](https://github.com/AsahelHT/DeepRL_SuperMario)**
#
#
# ---
#
# ## Resultado obtenido
#
# <figure style="text-align: center; margin-top: 20px;">
#   <img src="./media/gifs/PPO_CNN_3005_4.gif" alt="Mejor entrenamiento logrado" width="350">
#   <figcaption style="font-style: italic; color: #555; margin-top: 10px;">
#     🏆 Mejor agente entrenado: <strong>PPO_CNN_3005_4</strong>
#   </figcaption>
# </figure>
#
# ---
#
# ## Estructura del Notebook
#
# El notebook se organiza en **cuatro secciones principales**:
#
# 1. ⚙️ **Configuración del entorno**
# 2. 🛠️ **Modificación y ampliación**
# 3. 🧠 **Entrenamiento del agente**
# 4. 📈 **Evaluación de desempeño**
#
# Cada sección incluye comentarios y celdas auxiliares para facilitar la experimentación y comprensión del aprendizaje por refuerzo profundo.
#
# ---
# ---

# %% [markdown]
# ## 1. ⚙️ Configuración inicial del entorno
#
# Para ejecutar correctamente este notebook, se recomienda usar un entorno `conda` o equivalente con:
#
# - **Python 3.8**
# - Todas las dependencias detalladas en el archivo `requirements.txt` incluido con el proyecto
#
# Puedes crear el entorno ejecutando:
#
# ```bash
# conda create -n mario_rl python=3.8
# pip install -r requirements.txt
#
# ```
#
# Lo primero es importar las librerías necesarias para ejecutar el entorno:

# %%
import gymnasium as gym
# Gymnasium ofrece diferentes tipos de espacios para definir el espacio de acción y el espacio de observación.
# En este caso, usamos Box para definir un espacio de observación continuo, y Discrete para un espacio de acción discreto.
from gymnasium.spaces import Box, Discrete

# Para modificar el entorno de Gymnasium, usamos la clase Wrapper.
# Wrapper es una clase base que permite modificar el comportamiento de un entorno sin cambiar su implementación.
from gymnasium import Wrapper

# Del emulador de NES, importamos el espacio de acción que emula el joystick.
from nes_py.wrappers import JoypadSpace

# Importamos el entorno de Super Mario Bros.
import gym_super_mario_bros
# Como indica la documentacion, el entorno de Super Mario Bros. tiene diferentes espacios de acción.
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT, COMPLEX_MOVEMENT, RIGHT_ONLY

from gym.wrappers import GrayScaleObservation
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack, SubprocVecEnv
from stable_baselines3.common.callbacks import EvalCallback

from stable_baselines3.common.callbacks import BaseCallback

from stable_baselines3.common.results_plotter import load_results, ts2xy
from typing import Callable
import matplotlib.pyplot as plt
import os

import cv2
import numpy as np

from collections import deque
import torch
from typing import Callable

# Variables de configuración
# Puedes cambiar el mundo y el nivel para probar diferentes niveles de Super Mario Bros.
# También puedes cambiar el tipo de acción y el número de frames apilados.
WORLD = 1
STAGE = 1
ACTION_TYPE = RIGHT_ONLY 
N_FRAMES_STACK = 4

# %% [markdown]
# ---
# ---
# ## 2. 🛠️ Modificación y ampliación del entorno
#
# Se han realizado diversas mejoras sobre el entorno original de entrenamiento con el objetivo de optimizar el rendimiento del agente y adaptar el entorno a las necesidades específicas del experimento.
#
# <blockquote style="border-left: 4px solid #00bcd4; background: #f0faff; padding: 10px; color: #333;">
# 🔧 <strong>Modificaciones aplicadas:</strong>
# <ul style="margin-top: 10px;">
#   <li><strong>2.1 Preprocesado de la imagen:</strong> Reducción de tamaño, escala de grises y normalización de los fotogramas para facilitar el aprendizaje.</li>
#   <li><strong>2.2 Personalización de la función de recompensa:</strong> Ajustes para incentivar el avance en el escenario y penalizar acciones no productivas.</li>
#   <li><strong>2.3 Obtención de información temporal:</strong> Almacenamiento de estados anteriores para dotar al agente de una noción de secuencia (frame stacking).</li>
#   <li><strong>2.4 Creación del entorno de entrenamiento:</strong> Se implementa la función que permite crear un entorno aplicando todos los Wrappers anteriores.</li>
# </ul>
# </blockquote>

# %% [markdown]
# ### 2.1 Preprocesado de la imagen
#
# El primer paso consiste en aplicar un **preprocesado a la imagen** recibida del entorno para reducir su complejidad y hacer más eficiente el aprendizaje del agente.
#
# <blockquote style="border-left: 4px solid #4CAF50; background: #f9fff9; padding: 10px; color: #333;">
# 🖼️ <strong>Operaciones realizadas:</strong>
# <ul style="margin-top: 10px;">
#   <li><strong>Conversión a escala de grises:</strong> elimina el canal de color, conservando únicamente la información relevante.</li>
#   <li><strong>Reducción de tamaño:</strong> disminuye la resolución para acortar los tiempos de cómputo y reducir la dimensionalidad.</li>
#   <li><strong>Normalización:</strong> transforma los valores de píxel al rango <code>[0, 1]</code> para estabilizar el proceso de entrenamiento.</li>
# </ul>
# </blockquote>
#
# La función implementada toma como entrada la **observación en crudo** proporcionada por el entorno (una imagen RGB) y devuelve una versión preprocesada siguiendo los pasos anteriores:

# %%
# Dimensiones de la imagen procesada
HEIGHT = 84
WIDTH = 84

# Aplica un procesamiento a la imagen del entorno para que sea más fácil de manejar.
def process_frame(frame):
    if frame is not None:
        if len(frame.shape) == 3 and frame.shape[2] == 3:
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        resized = cv2.resize(frame, (WIDTH, HEIGHT))
        normalized = resized / 255.0

        return normalized.astype(np.float32)  # Ensure the output is float32
    else:
        return np.zeros((HEIGHT, WIDTH), dtype=np.float32)

# %% [markdown]
# Con esto, pasamos de tener una observación de dimensiones 3x256x240, a 1xHEIGHTXWIDHT, reduciendo drásticamente nuestra representación del estado del mundo de Mario.

# %% [markdown]
# ### 2.2 Personalización de la función de recompensa
#
# La función de recompensa ha sido diseñada para **alinear el comportamiento del agente con los objetivos del juego**, incentivando el progreso hacia la derecha, la rapidez y la supervivencia.
#
# <blockquote style="border-left: 4px solid #ff9800; background: #fffaf0; padding: 10px; color: #333;">
# 🎯 <strong>Componentes de la recompensa:</strong>
# <ul style="margin-top: 10px;">
#   <li><strong>Progreso horizontal:</strong> se recompensa moverse a la derecha.</li>
#   <li><strong>Puntuación:</strong> se recompensa la obtención de puntos.</li>
#   <li><strong>Muerte del agente:</strong> penalización significativa por perder una vida.</li>
#   <li><strong>Bandera final:</strong> recompensa alta por completar el nivel.</li>
# </ul>
# </blockquote>
#
# Esta combinación de recompensas y penalizaciones permite guiar el entrenamiento del agente hacia una estrategia **eficiente y segura**.

# %%
class CustomReward(Wrapper):
    def __init__(self, env=None):
        super(CustomReward, self).__init__(env)
        self.observation_space = Box(low=0, high=255, shape=(HEIGHT, WIDTH))
        self.action_space = Discrete(env.action_space.n)
        self.info = {}
        self.prev_x = 40
        self.prev_score = 0 
        #self.prev_time = None
        self.prev_lives = 2

    def step(self, action):
        obs, reward, done, trunk, info = self.env.step(action)
        self.info = info
        processed_img = process_frame(obs)

        reward = 0.0

        delta_x_reward = 0.0
        delta_score_reward = 0.0
        flag_reward = 0.0
        death_penalty = 0.0

        # Penalizacion si muere o no llega a la meta
        current_lives = info.get('life', self.prev_lives)
        if current_lives < self.prev_lives:
            death_penalty -= 50.0  

        # Recompensa por avanzar, penalizacion por quedarse quieto
        delta_x = info['x_pos'] - self.prev_x
        if delta_x > 0:
            delta_x_reward += delta_x * 0.1
        else:
            delta_x_reward -= 0.01
        # Recompensa si llega a la meta
        if info.get('flag_get', False):
            flag_reward += 100.0

        # Recompensa por incremento en la puntuacion
        delta_score = info['score'] - self.prev_score
        if delta_score > 0:
            delta_score_reward += delta_score * 0.01  

        self.prev_lives = current_lives

        # Actualización de valores previos
        self.prev_x = info['x_pos']
        self.prev_score = info['score']  

        # Función de recompensa 
        reward = death_penalty + delta_x_reward + flag_reward + delta_score_reward

        return processed_img, reward, done, trunk, info

    def reset(self, **kwargs):

        self.prev_score = 0
        self.prev_x = 40
        self.prev_lives = 2

        obs, info = self.env.reset()
        obs = process_frame(obs)
        return obs, info

# %% [markdown]
# ### 2.3 Obtención de información temporal
#
# Para que el agente sea capaz de interpretar el movimiento en el entorno (como la velocidad o dirección de los objetos), es necesario proporcionarle **información temporal**. Esto se consigue mediante el uso de **wrappers personalizados**.
#
# <blockquote style="border-left: 4px solid #3f51b5; background: #f4f6ff; padding: 10px; color: #333;">
# ⏳ <strong>Mecanismos implementados:</strong>
# <ul style="margin-top: 10px;">
#   <li><strong>Apilamiento de N frames consecutivos:</strong> se almacena una secuencia de <code>N</code> observaciones recientes, dando lugar a un tensor de forma <code>(N, height, width)</code>. Esto permite al agente inferir el movimiento de los elementos en pantalla durante el tiempo.</li>
#   <li><strong>Repetición de acciones:</strong> se mantiene la misma acción durante varios frames consecutivos, mejorando la estabilidad de las decisiones y reduce acciones erráticas.</li>
# </ul>
# </blockquote>
#
# Este enfoque permite simular una memoria visual de corto plazo, **mejorando la capacidad de planificación del agente** y facilitando el aprendizaje en entornos dinámicos como *Super Mario Bros*.

# %%
# Wrapper para apilar frames del entorno.
# Esta clase se encargará de apilar los frames del entorno para crear un stack de frames.
# Esto es útil para que el agente pueda ver el movimiento de Mario y aprender a jugar mejor.

N_FRAMES = 4
REPEAT_ACTION = 4  # Número de veces que se repetirá la acción

class CustomStackAndRepeat(Wrapper):
    def __init__(self, env, n_frames=N_FRAMES, repeat=REPEAT_ACTION):
        super(CustomStackAndRepeat, self).__init__(env)
        self._n_frames = n_frames
        self.repeat = repeat

        # Espacio de observación actualizado
        self.observation_space = Box(low=0, high=1.0, shape=(self._n_frames, HEIGHT, WIDTH), dtype=np.float32)

        # Deque para almacenar los últimos frames
        self.frames = deque(maxlen=n_frames)

    def step(self, action):
        total_reward = 0.0
        done = False
        trunk = False
        info = {}
        
        for _ in range(self.repeat):
            obs, reward, done, trunk, info = self.env.step(action)
            processed_obs = process_frame(obs)
            self.frames.append(processed_obs)
            total_reward += reward
            if done or trunk:
                break

        # Si no hay suficientes frames aún, rellenamos con el último
        #while len(self.frames) < self._n_frames:
        #    self.frames.append(processed_obs)

        # Creamos la observación apilada
        stacked_obs = np.stack(self.frames, axis=0)
        return stacked_obs, total_reward, done, trunk, info

    def reset(self, **kwargs):
        obs, info = self.env.reset()
        processed_obs = process_frame(obs)

        self.frames = deque([processed_obs] * self._n_frames, maxlen=self._n_frames)
        stacked_obs = np.stack(self.frames, axis=0)
        return stacked_obs, info

# %% [markdown]
# ### 2.4 Creación del entorno de entrenamiento
#
# Una vez definidos los **wrappers personalizados**, se crea el entorno de entrenamiento aplicándolos de forma modular y estructurada.
#
# <blockquote style="border-left: 4px solid #009688; background: #e6f9f7; padding: 10px; color: #333;">
# 🧩 <strong>Wrappers aplicados:</strong>
# <ul style="margin-top: 10px;">
#   <li><strong>Recompensa personalizada:</strong> ajusta los refuerzos según el rendimiento deseado.</li>
#   <li><strong>Stack de frames:</strong> añade memoria temporal al agente.</li>
#   <li><strong>Repetición de acciones:</strong> estabiliza las decisiones reduciendo el ruido de entrada.</li>
# </ul>
# </blockquote>
#
# A continuación, se define la función encargada de crear y devolver un entorno completamente configurado para el entrenamiento del agente:

# %%
def create_mario_env(world, stage, action_type=RIGHT_ONLY, n_frames_stack=4, render_mode="rgb_array"):    
    # Crea el entorno base de Super Mario Bros. con el mundo y el nivel especificados.
    env = gym_super_mario_bros.make(f"SuperMarioBros-{world}-{stage}-v0", apply_api_compatibility=True, render_mode=render_mode)

    # Envuelve el entorno en el wrapper del Joystick de NES para poder elegir las acciones.
    env = JoypadSpace(env, action_type)

    # Envuelve el entorno en los wrappers de CustomStackFrames y CustomReward.
    env = CustomReward(env)
    env = CustomStackAndRepeat(env, n_frames=n_frames_stack)
    
    return env

# %% [markdown]
# ---
# ---
# ## 3. 🧠 Entrenamiento del agente con Stable Baselines3
#
# Para llevar a cabo el entrenamiento del agente, se ha utilizado el algoritmo **PPO (Proximal Policy Optimization)** en combinación con una arquitectura basada en **Redes Neuronales Convolucionales (CNNs)**, mediante la librería 📦 <code>Stable-Baselines3</code>.
#
# <blockquote style="border-left: 4px solid #673ab7; background: #f3f0ff; padding: 10px; color: #333;">
# 🔍 <strong>Justificación técnica:</strong>
# <ul style="margin-top: 10px;">
#   <li><strong>PPO:</strong> algoritmo robusto y eficiente para entornos con observaciones visuales complejas.</li>
#   <li><strong>CNN:</strong> excelente rendimiento en entornos visuales como Super Mario Bros, donde la entrada es una imagen procesada.</li>
# </ul>
# </blockquote>
#
# La elección concreta de esta arquitectura se detalla con mayor profundidad en la <strong>memoria de la práctica</strong>, incluyendo análisis comparativos y experimentación con distintas configuraciones.

# %% [markdown]
# ### 3.1 Implementación de entornos vectorizados
#
# Para mejorar la eficiencia del entrenamiento y aprovechar al máximo los recursos disponibles, se utiliza **vectorización de entornos**. Esto permite ejecutar múltiples entornos en paralelo, acelerando la recopilación de experiencias del agente.
#
# <blockquote style="border-left: 4px solid #607d8b; background: #f5f7f9; padding: 10px; color: #333;">
# ⚙️ <strong>Procedimiento:</strong>
# <ul style="margin-top: 10px;">
#   <li>Se define el número de entornos paralelos a lanzar.</li>
#   <li>Se encapsula la función <code>make_env()</code> para permitir su uso en múltiples procesos.</li>
#   <li>Se utiliza <code>SubprocVecEnv</code> o <code>DummyVecEnv</code> de <code>Stable-Baselines3</code> según las necesidades del sistema.</li>
# </ul>
# </blockquote>
#
# Esto permite que el agente recopile experiencias de varios episodios simultáneamente, lo que **reduce significativamente el tiempo total de entrenamiento** y mejora la estabilidad del aprendizaje.

# %%
# Vamos a utilizar la función make_vec_env para crear un entorno vectorizado.
# Esta función crea un entorno vectorizado utilizando el entorno base que hemos creado anteriormente.
# El número de entornos vectorizados por defect es 4, pero cambiadlo en base a vuestra CPU y analisis de rendimiento.
NUM_ENVS = 8

env = make_vec_env(
    lambda: create_mario_env(WORLD, STAGE, ACTION_TYPE, n_frames_stack=N_FRAMES_STACK, render_mode="rgb_array"),
    n_envs=NUM_ENVS,
    vec_env_cls=DummyVecEnv,
    monitor_dir="./mario_monitor_dir/",
    seed=33
)

print("Vectorized environment created.")
print("Observation space:", env.observation_space)
print("Action space:", env.action_space)
# Out:
# c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SuperMarioBros-1-1-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\gym\envs\registration.py:627: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes', 'video.frames_per_second']
#   logger.warn(
# Vectorized environment created.
# Observation space: Box(0.0, 1.0, (4, 84, 84), float32)
# Action space: Discrete(5)

# %% [markdown]
# ### 3.2 Creación de callbacks durante el entrenamiento
#
# Durante el entrenamiento del agente, se utilizan **callbacks personalizados** para monitorizar el progreso y guardar los modelos periódicamente. Esto permite evitar la pérdida de datos y analizar el comportamiento del agente de forma más controlada.
#
# <blockquote style="border-left: 4px solid #9c27b0; background: #fdf5ff; padding: 10px; color: #333;">
# 🛠️ <strong>Callbacks utilizados:</strong>
# <ul style="margin-top: 10px;">
#   <li><strong>TrainAndLogCallback:</strong> guarda el modelo cada cierto número de pasos y registra el progreso del entrenamiento.</li>
# </ul>
# </blockquote>
#
# A continuación, se muestra la implementación del callback principal utilizado:

# %%
# Callback para guardar el modelo y registrar la información durante el entrenamiento.
# Este callback se ejecuta cada cierto número de pasos y guarda el modelo en la ruta especificada.
class TrainAndLogCallback(BaseCallback):
    def __init__(self, check_freq, save_path, start_steps=0, verbose=1):
        super(TrainAndLogCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path
        self.start_steps = start_steps

    def _init_callback(self):
        # Creamos la carpeta de guardado si no existe.
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        # Guardamos el modelo cada check_freq pasos.
        if self.n_calls % self.check_freq == 0:
            if self.save_path is not None:
                self.model.save(os.path.join(self.save_path, "model_{}".format(self.n_calls + int(self.start_steps))))
        return True

# %% [markdown]
# ### 3.3 Funciones adicionales
#
# Se define una función auxiliar llamada <code>linear_schedule()</code>, utilizada para aplicar una **disminución lineal del learning rate** a lo largo del entrenamiento. Esta técnica es común en problemas de aprendizaje por refuerzo y puede aportar varias ventajas clave:
#
# <blockquote style="border-left: 4px solid #03a9f4; background: #f0faff; padding: 10px; color: #333;">
# ✅ <strong>Ventajas: </strong>
# <ul style="margin-top: 10px;">
#   <li> <strong>Evita sobreentrenamiento:</strong> reduce los ajustes agresivos en etapas finales, estabilizando la política.</li>
#   <li> <strong>Favorece un aprendizaje rápido al inicio:</strong> una tasa alta al principio permite mayor exploración.</li>
#   <li> <strong>Mejora la convergencia:</strong> muchos algoritmos de RL funcionan mejor con <em>learning rate decay</em>.</li>
# </ul>
# </blockquote>
#
# A continuación, se muestra la implementación de la función:

# %%
def learning_rateDecay(initial_value: float) -> Callable[[float], float]:
    def func(progress_remaining: float) -> float:
        return progress_remaining * initial_value

    return func

# %% [markdown]
# ### 3.4 Entrenamiento de la política
#
# Una vez configurado el entorno, las funciones auxiliares y los callbacks, se crea el modelo PPO con los parámetros deseados y se inicia el proceso de entrenamiento.
#
# <blockquote style="border-left: 4px solid #4caf50; background: #f4fff4; padding: 10px; color: #333;">
# <strong>🏋️‍♂️ lujo del entrenamiento:</strong>
# <ul style="margin-top: 10px;">
#   <li> Se instancia el modelo <code>PPO</code> utilizando una política <code>'CnnPolicy'</code>.</li>
#   <li> Se utiliza <code>linear_schedule()</code> para disminuir el learning rate progresivamente.</li>
#   <li> Se integran los callbacks personalizados para evaluar, guardar y registrar el progreso.</li>
#   <li> Finalizado el entrenamiento, se guarda el modelo y se visualizan los resultados obtenidos.</li>
# </ul>
# </blockquote>
#
# A continuación, se muestra el bloque de código para ejecutar el entrenamiento:

# %%
# Inicializamos el modelo con PPO y una política MLP
model = PPO(
    "CnnPolicy",
    env,
    verbose=1,
    tensorboard_log="./mario_logs/",
    learning_rate=learning_rateDecay(3.5e-4),
    n_steps=512,
    policy_kwargs={"normalize_images": False}  
)

print("Modelo PPO inicializado correctamente.")

# Inicializamos el callback para guardar el modelo y registrar la información durante el entrenamiento
cb = TrainAndLogCallback(check_freq=10000, save_path="./mario_models/", start_steps=0, verbose=1)
# eval_callback = EvalCallback(env, eval_freq=10000, deterministic=True, render=False)

# Número de pasos para el entrenamiento
total_timesteps = 1.5e6

# Entrenamos el modelo
model.learn(total_timesteps=total_timesteps, callback=cb)

data = load_results("./mario_monitor_dir/")
x, y = ts2xy(data, 'timesteps')

plt.plot(x, y)
plt.xlabel("Timesteps")
plt.ylabel("Episode Reward")
plt.title("Recompensa por episodio")
plt.show()

# Guardamos el modelo final
model.save("mario_final_model")

# Cerramos el entorno
env.close()
# Out:
# Using cuda device
# Modelo PPO inicializado correctamente.
# Logging to ./mario_logs/PPO_31
# c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\PracticaRLMario\.venv\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 80.9     |
# |    ep_rew_mean     | 48.2     |
# | time/              |          |
# |    fps             | 124      |
# |    iterations      | 1        |
# |    time_elapsed    | 33       |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | 61.3        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 2           |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014261128 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 7.51e-06    |
# |    learning_rate        | 0.000349    |
# |    loss                 | 4.48        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00308    |
# |    value_loss           | 19.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 215         |
# |    ep_rew_mean          | 73.6        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 3           |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011617647 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.572       |
# |    learning_rate        | 0.000348    |
# |    loss                 | 5.5         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00296    |
# |    value_loss           | 17.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 71.1        |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 4           |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009979559 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.000347    |
# |    loss                 | 10.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00158    |
# |    value_loss           | 21          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | 70.6        |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 5           |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007946755 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.000346    |
# |    loss                 | 22.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00266    |
# |    value_loss           | 32.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 162         |
# |    ep_rew_mean          | 73.7        |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 6           |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008364955 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.000345    |
# |    loss                 | 19.3        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.00174     |
# |    value_loss           | 40.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | 78.6        |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 7           |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011722315 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.000344    |
# |    loss                 | 11.1        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.000246    |
# |    value_loss           | 38          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 131         |
# |    ep_rew_mean          | 77.3        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 8           |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.016530242 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.53        |
# |    learning_rate        | 0.000343    |
# |    loss                 | 23.6        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00343     |
# |    value_loss           | 49.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 131        |
# |    ep_rew_mean          | 84.5       |
# | time/                   |            |
# |    fps                  | 107        |
# |    iterations           | 9          |
# |    time_elapsed         | 342        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01231084 |
# |    clip_fraction        | 0.226      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.48      |
# |    explained_variance   | 0.459      |
# |    learning_rate        | 0.000342   |
# |    loss                 | 17.8       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.000136  |
# |    value_loss           | 51.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | 82.3        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 10          |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015700607 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.000341    |
# |    loss                 | 23.9        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00151     |
# |    value_loss           | 52.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | 82.7        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 11          |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.014302013 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.336       |
# |    learning_rate        | 0.00034     |
# |    loss                 | 35.8        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.000136   |
# |    value_loss           | 71.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | 79.5        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 12          |
# |    time_elapsed         | 458         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011423779 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.451       |
# |    learning_rate        | 0.000339    |
# |    loss                 | 25.5        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00354     |
# |    value_loss           | 58.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | 76          |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 13          |
# |    time_elapsed         | 496         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012442802 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.000339    |
# |    loss                 | 41.1        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00113     |
# |    value_loss           | 73.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | 79.8        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 14          |
# |    time_elapsed         | 534         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012933005 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.000338    |
# |    loss                 | 41.3        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00168     |
# |    value_loss           | 61.8        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 110       |
# |    ep_rew_mean          | 77.9      |
# | time/                   |           |
# |    fps                  | 107       |
# |    iterations           | 15        |
# |    time_elapsed         | 572       |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.0117541 |
# |    clip_fraction        | 0.175     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.23     |
# |    explained_variance   | 0.369     |
# |    learning_rate        | 0.000337  |
# |    loss                 | 41        |
# |    n_updates            | 140       |
# |    policy_gradient_loss | 0.00124   |
# |    value_loss           | 67.4      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 121        |
# |    ep_rew_mean          | 85.3       |
# | time/                   |            |
# |    fps                  | 107        |
# |    iterations           | 16         |
# |    time_elapsed         | 610        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.01295392 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | 0.418      |
# |    learning_rate        | 0.000336   |
# |    loss                 | 37.3       |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.001      |
# |    value_loss           | 68.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 107         |
# |    ep_rew_mean          | 79.5        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 17          |
# |    time_elapsed         | 647         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.012674486 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.000335    |
# |    loss                 | 30.8        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0017      |
# |    value_loss           | 64.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 114         |
# |    ep_rew_mean          | 85          |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 18          |
# |    time_elapsed         | 686         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.014301935 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.000334    |
# |    loss                 | 18.4        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.000661    |
# |    value_loss           | 57.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 119         |
# |    ep_rew_mean          | 88.9        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 19          |
# |    time_elapsed         | 724         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.013789989 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.000333    |
# |    loss                 | 27.3        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00124    |
# |    value_loss           | 50.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 132         |
# |    ep_rew_mean          | 93.2        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 20          |
# |    time_elapsed         | 762         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.016960302 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.514       |
# |    learning_rate        | 0.000332    |
# |    loss                 | 37.7        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00025    |
# |    value_loss           | 54.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 94.1        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 21          |
# |    time_elapsed         | 800         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.016976468 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.000331    |
# |    loss                 | 26.9        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00199    |
# |    value_loss           | 43          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | 92.4        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 22          |
# |    time_elapsed         | 838         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.021008657 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.00033     |
# |    loss                 | 21          |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00172    |
# |    value_loss           | 33.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | 89.7        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 23          |
# |    time_elapsed         | 876         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.035420015 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.000329    |
# |    loss                 | 24          |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00221     |
# |    value_loss           | 50.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 120         |
# |    ep_rew_mean          | 84.3        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 24          |
# |    time_elapsed         | 914         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.017611306 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.000328    |
# |    loss                 | 18.4        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00279    |
# |    value_loss           | 53.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 115        |
# |    ep_rew_mean          | 82.1       |
# | time/                   |            |
# |    fps                  | 107        |
# |    iterations           | 25         |
# |    time_elapsed         | 953        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01790253 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 0.523      |
# |    learning_rate        | 0.000327   |
# |    loss                 | 22.5       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.000134  |
# |    value_loss           | 55         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | 82.7        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 26          |
# |    time_elapsed         | 991         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.013200104 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.526       |
# |    learning_rate        | 0.000326    |
# |    loss                 | 15.6        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00273    |
# |    value_loss           | 57.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 121         |
# |    ep_rew_mean          | 85.1        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 27          |
# |    time_elapsed         | 1030        |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.020360876 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.529       |
# |    learning_rate        | 0.000325    |
# |    loss                 | 23.3        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.000111    |
# |    value_loss           | 44          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | 89.1        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 28          |
# |    time_elapsed         | 1069        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.034632735 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.000324    |
# |    loss                 | 24.2        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00321     |
# |    value_loss           | 54.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 128         |
# |    ep_rew_mean          | 90          |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 29          |
# |    time_elapsed         | 1107        |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.019940682 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.000323    |
# |    loss                 | 34.2        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00377     |
# |    value_loss           | 56.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 128         |
# |    ep_rew_mean          | 90.9        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 30          |
# |    time_elapsed         | 1145        |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.014199235 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.479       |
# |    learning_rate        | 0.000322    |
# |    loss                 | 23.9        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 61.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | 94.2        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 31          |
# |    time_elapsed         | 1182        |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.029818295 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.475       |
# |    learning_rate        | 0.000321    |
# |    loss                 | 19.5        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00566     |
# |    value_loss           | 54.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 134        |
# |    ep_rew_mean          | 93.6       |
# | time/                   |            |
# |    fps                  | 107        |
# |    iterations           | 32         |
# |    time_elapsed         | 1219       |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.03310159 |
# |    clip_fraction        | 0.254      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.15      |
# |    explained_variance   | 0.692      |
# |    learning_rate        | 0.00032    |
# |    loss                 | 26.8       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.00171   |
# |    value_loss           | 46         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | 96.1        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 33          |
# |    time_elapsed         | 1258        |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.023457186 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.000319    |
# |    loss                 | 23          |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.0011      |
# |    value_loss           | 65.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 128         |
# |    ep_rew_mean          | 94.5        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 34          |
# |    time_elapsed         | 1299        |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.020574246 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.000318    |
# |    loss                 | 25.3        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00207    |
# |    value_loss           | 53.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | 93.5        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 35          |
# |    time_elapsed         | 1338        |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.017115535 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.000318    |
# |    loss                 | 40.1        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.000969    |
# |    value_loss           | 64.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 121         |
# |    ep_rew_mean          | 90.3        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 36          |
# |    time_elapsed         | 1378        |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.013249392 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.446       |
# |    learning_rate        | 0.000317    |
# |    loss                 | 25.5        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.000792    |
# |    value_loss           | 65.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | 89.3        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 37          |
# |    time_elapsed         | 1419        |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.025843296 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.000316    |
# |    loss                 | 30.3        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00208     |
# |    value_loss           | 63.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | 91.7        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 38          |
# |    time_elapsed         | 1459        |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.014835045 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.000315    |
# |    loss                 | 30.4        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.000498   |
# |    value_loss           | 52.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 123        |
# |    ep_rew_mean          | 86.5       |
# | time/                   |            |
# |    fps                  | 106        |
# |    iterations           | 39         |
# |    time_elapsed         | 1499       |
# |    total_timesteps      | 159744     |
# | train/                  |            |
# |    approx_kl            | 0.01476906 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.12      |
# |    explained_variance   | 0.509      |
# |    learning_rate        | 0.000314   |
# |    loss                 | 31.4       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0034    |
# |    value_loss           | 54.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | 84.2        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 40          |
# |    time_elapsed         | 1540        |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.012942696 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.000313    |
# |    loss                 | 27.8        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00029     |
# |    value_loss           | 63.6        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 124       |
# |    ep_rew_mean          | 87.9      |
# | time/                   |           |
# |    fps                  | 106       |
# |    iterations           | 41        |
# |    time_elapsed         | 1580      |
# |    total_timesteps      | 167936    |
# | train/                  |           |
# |    approx_kl            | 0.0211359 |
# |    clip_fraction        | 0.183     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.08     |
# |    explained_variance   | 0.559     |
# |    learning_rate        | 0.000312  |
# |    loss                 | 24.2      |
# |    n_updates            | 400       |
# |    policy_gradient_loss | -0.00139  |
# |    value_loss           | 52.3      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 95.4        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 42          |
# |    time_elapsed         | 1622        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.016490625 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.000311    |
# |    loss                 | 18.7        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.000171   |
# |    value_loss           | 35.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 94.3        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 43          |
# |    time_elapsed         | 1662        |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.019954726 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.488       |
# |    learning_rate        | 0.00031     |
# |    loss                 | 37.3        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00244    |
# |    value_loss           | 58.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | 98.3        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 44          |
# |    time_elapsed         | 1701        |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.014481386 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.000309    |
# |    loss                 | 18.8        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00303    |
# |    value_loss           | 61          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | 93          |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 45          |
# |    time_elapsed         | 1741        |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.018433053 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.99       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.000308    |
# |    loss                 | 25          |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 41.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 137        |
# |    ep_rew_mean          | 96.5       |
# | time/                   |            |
# |    fps                  | 105        |
# |    iterations           | 46         |
# |    time_elapsed         | 1781       |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.02699039 |
# |    clip_fraction        | 0.231      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.977     |
# |    explained_variance   | 0.539      |
# |    learning_rate        | 0.000307   |
# |    loss                 | 41.8       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.00311   |
# |    value_loss           | 57.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | 95.5        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 47          |
# |    time_elapsed         | 1821        |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.019090239 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.000306    |
# |    loss                 | 43.6        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00343     |
# |    value_loss           | 56          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 125         |
# |    ep_rew_mean          | 91.6        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 48          |
# |    time_elapsed         | 1860        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.018537655 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.000305    |
# |    loss                 | 20.4        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 55          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | 99.8        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 49          |
# |    time_elapsed         | 1900        |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.016870014 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.000304    |
# |    loss                 | 22.7        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00236    |
# |    value_loss           | 47.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 50          |
# |    time_elapsed         | 1940        |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.025779959 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.000303    |
# |    loss                 | 16          |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00109     |
# |    value_loss           | 36.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 51          |
# |    time_elapsed         | 1980        |
# |    total_timesteps      | 208896      |
# | train/                  |             |
# |    approx_kl            | 0.030707609 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.000302    |
# |    loss                 | 17.4        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00469     |
# |    value_loss           | 40.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 52          |
# |    time_elapsed         | 2018        |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.021557674 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.000301    |
# |    loss                 | 10.6        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00123     |
# |    value_loss           | 42.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 147        |
# |    ep_rew_mean          | 105        |
# | time/                   |            |
# |    fps                  | 105        |
# |    iterations           | 53         |
# |    time_elapsed         | 2056       |
# |    total_timesteps      | 217088     |
# | train/                  |            |
# |    approx_kl            | 0.01888922 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.507      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 22.8       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.00251   |
# |    value_loss           | 57.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 139        |
# |    ep_rew_mean          | 102        |
# | time/                   |            |
# |    fps                  | 105        |
# |    iterations           | 54         |
# |    time_elapsed         | 2094       |
# |    total_timesteps      | 221184     |
# | train/                  |            |
# |    approx_kl            | 0.02439773 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.608      |
# |    learning_rate        | 0.000299   |
# |    loss                 | 23.9       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.00339   |
# |    value_loss           | 46.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 55          |
# |    time_elapsed         | 2132        |
# |    total_timesteps      | 225280      |
# | train/                  |             |
# |    approx_kl            | 0.021416504 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.000298    |
# |    loss                 | 13.5        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.003       |
# ...
# |    iterations           | 350          |
# |    time_elapsed         | 13602        |
# |    total_timesteps      | 1433600      |
# | train/                  |              |
# |    approx_kl            | 0.0051946673 |
# |    clip_fraction        | 0.0372       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.125       |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 1.64e-05     |
# |    loss                 | 0.0469       |
# |    n_updates            | 3490         |
# |    policy_gradient_loss | -0.00336     |
# |    value_loss           | 0.113        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 276          |
# |    ep_rew_mean          | 413          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 351          |
# |    time_elapsed         | 13642        |
# |    total_timesteps      | 1437696      |
# | train/                  |              |
# |    approx_kl            | 0.0023960741 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.132       |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 1.55e-05     |
# |    loss                 | 0.0756       |
# |    n_updates            | 3500         |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 1.95         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 276          |
# |    ep_rew_mean          | 411          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 352          |
# |    time_elapsed         | 13682        |
# |    total_timesteps      | 1441792      |
# | train/                  |              |
# |    approx_kl            | 0.0030468665 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.142       |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 1.45e-05     |
# |    loss                 | 0.137        |
# |    n_updates            | 3510         |
# |    policy_gradient_loss | -0.00889     |
# |    value_loss           | 1.38         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 275          |
# |    ep_rew_mean          | 411          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 353          |
# |    time_elapsed         | 13722        |
# |    total_timesteps      | 1445888      |
# | train/                  |              |
# |    approx_kl            | 0.0071574273 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.128       |
# |    explained_variance   | 0.854        |
# |    learning_rate        | 1.36e-05     |
# |    loss                 | 12           |
# |    n_updates            | 3520         |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 11.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 276          |
# |    ep_rew_mean          | 413          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 354          |
# |    time_elapsed         | 13761        |
# |    total_timesteps      | 1449984      |
# | train/                  |              |
# |    approx_kl            | 0.0028213486 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.119       |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 1.26e-05     |
# |    loss                 | 0.0349       |
# |    n_updates            | 3530         |
# |    policy_gradient_loss | -0.00522     |
# |    value_loss           | 0.241        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 278          |
# |    ep_rew_mean          | 416          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 355          |
# |    time_elapsed         | 13801        |
# |    total_timesteps      | 1454080      |
# | train/                  |              |
# |    approx_kl            | 0.0038154195 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.13        |
# |    explained_variance   | 0.936        |
# |    learning_rate        | 1.17e-05     |
# |    loss                 | 1            |
# |    n_updates            | 3540         |
# |    policy_gradient_loss | -0.0079      |
# |    value_loss           | 1.76         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 278         |
# |    ep_rew_mean          | 416         |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 356         |
# |    time_elapsed         | 13842       |
# |    total_timesteps      | 1458176     |
# | train/                  |             |
# |    approx_kl            | 0.002144174 |
# |    clip_fraction        | 0.0174      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.132      |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 1.07e-05    |
# |    loss                 | 8.28        |
# |    n_updates            | 3550        |
# |    policy_gradient_loss | -0.00351    |
# |    value_loss           | 2.3         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 278          |
# |    ep_rew_mean          | 416          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 357          |
# |    time_elapsed         | 13882        |
# |    total_timesteps      | 1462272      |
# | train/                  |              |
# |    approx_kl            | 0.0026720958 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.127       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 9.76e-06     |
# |    loss                 | 0.00832      |
# |    n_updates            | 3560         |
# |    policy_gradient_loss | -0.00439     |
# |    value_loss           | 0.0634       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 278          |
# |    ep_rew_mean          | 416          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 358          |
# |    time_elapsed         | 13922        |
# |    total_timesteps      | 1466368      |
# | train/                  |              |
# |    approx_kl            | 0.0010826827 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.127       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 8.8e-06      |
# |    loss                 | 0.324        |
# |    n_updates            | 3570         |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 0.426        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 278          |
# |    ep_rew_mean          | 418          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 359          |
# |    time_elapsed         | 13963        |
# |    total_timesteps      | 1470464      |
# | train/                  |              |
# |    approx_kl            | 0.0028615235 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.119       |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 7.85e-06     |
# |    loss                 | 9.77         |
# |    n_updates            | 3580         |
# |    policy_gradient_loss | 0.000311     |
# |    value_loss           | 11.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 277          |
# |    ep_rew_mean          | 415          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 360          |
# |    time_elapsed         | 14002        |
# |    total_timesteps      | 1474560      |
# | train/                  |              |
# |    approx_kl            | 0.0016786216 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.103       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 6.89e-06     |
# |    loss                 | 0.0636       |
# |    n_updates            | 3590         |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 0.253        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 277          |
# |    ep_rew_mean          | 415          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 361          |
# |    time_elapsed         | 14044        |
# |    total_timesteps      | 1478656      |
# | train/                  |              |
# |    approx_kl            | 0.0016099174 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.1         |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 5.94e-06     |
# |    loss                 | 1.19         |
# |    n_updates            | 3600         |
# |    policy_gradient_loss | 0.000712     |
# |    value_loss           | 35.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 296         |
# |    ep_rew_mean          | 411         |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 362         |
# |    time_elapsed         | 14085       |
# |    total_timesteps      | 1482752     |
# | train/                  |             |
# |    approx_kl            | 0.002955515 |
# |    clip_fraction        | 0.0142      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.113      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 4.98e-06    |
# |    loss                 | 2.92        |
# |    n_updates            | 3610        |
# |    policy_gradient_loss | -0.0024     |
# |    value_loss           | 3.77        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 296           |
# |    ep_rew_mean          | 411           |
# | time/                   |               |
# |    fps                  | 105           |
# |    iterations           | 363           |
# |    time_elapsed         | 14126         |
# |    total_timesteps      | 1486848       |
# | train/                  |               |
# |    approx_kl            | 0.00057055976 |
# |    clip_fraction        | 0.00242       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.109        |
# |    explained_variance   | 0.995         |
# |    learning_rate        | 4.02e-06      |
# |    loss                 | 1.24          |
# |    n_updates            | 3620          |
# |    policy_gradient_loss | -0.000455     |
# |    value_loss           | 2.28          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 294          |
# |    ep_rew_mean          | 408          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 364          |
# |    time_elapsed         | 14167        |
# |    total_timesteps      | 1490944      |
# | train/                  |              |
# |    approx_kl            | 0.0015526471 |
# |    clip_fraction        | 0.0158       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.115       |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 3.07e-06     |
# |    loss                 | 0.0387       |
# |    n_updates            | 3630         |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 0.246        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 295           |
# |    ep_rew_mean          | 408           |
# | time/                   |               |
# |    fps                  | 105           |
# |    iterations           | 365           |
# |    time_elapsed         | 14209         |
# |    total_timesteps      | 1495040       |
# | train/                  |               |
# |    approx_kl            | 0.00028600678 |
# |    clip_fraction        | 0.000781      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.123        |
# |    explained_variance   | 0.638         |
# |    learning_rate        | 2.11e-06      |
# |    loss                 | 4.2           |
# |    n_updates            | 3640          |
# |    policy_gradient_loss | -0.000244     |
# |    value_loss           | 23.5          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 294          |
# |    ep_rew_mean          | 408          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 366          |
# |    time_elapsed         | 14250        |
# |    total_timesteps      | 1499136      |
# | train/                  |              |
# |    approx_kl            | 0.0004737132 |
# |    clip_fraction        | 0.00356      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.117       |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 1.16e-06     |
# |    loss                 | 0.273        |
# |    n_updates            | 3650         |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 1.07         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 295          |
# |    ep_rew_mean          | 411          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 367          |
# |    time_elapsed         | 14292        |
# |    total_timesteps      | 1503232      |
# | train/                  |              |
# |    approx_kl            | 1.427409e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.116       |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 2.02e-07     |
# |    loss                 | 0.111        |
# |    n_updates            | 3660         |
# |    policy_gradient_loss | -0.000159    |
# |    value_loss           | 1.46         |
# ------------------------------------------

# %% [markdown]
# ---
# ---
# ## 4. 📈 Evaluación de la política
#
# Una vez finalizado el entrenamiento, se procede a **evaluar el rendimiento** del modelo entrenado en un entorno independiente. El objetivo es medir su capacidad para generalizar, sin influencias del entorno de entrenamiento.
#
# <blockquote style="border-left: 4px solid #2196f3; background: #f0f8ff; padding: 10px; color: #333;">
#  <strong>📊 Métricas obtenidas:</strong>
# <ul style="margin-top: 10px;">
#   <li><strong>Recompensa media:</strong> indica el rendimiento promedio por episodio.</li>
#   <li><strong>Recompensa máxima y mínima:</strong> muestran la estabilidad del comportamiento.</li>
#   <li><strong>Número de episodios:</strong> define el tamaño de la muestra evaluada.</li>
# </ul>
# </blockquote>
#
# La evaluación se realiza utilizando funciones proporcionadas por <code>Stable-Baselines3</code> como <code>evaluate_policy()</code>, y puede incluir visualización de episodios o almacenamiento de resultados para análisis posterior.

# %% [markdown]
# ### 4.1 Visualización del comportamiento del agente
#
# En la siguiente celda se realiza una **evaluación visual del modelo entrenado**. El agente se ejecuta durante un número definido de episodios, y su comportamiento se registra en tiempo real.
#
# <blockquote style="border-left: 4px solid #00acc1; background: #e0f7fa; padding: 10px; color: #333;">
# <strong>🎥 Objetivo:</strong> Evaluar y capturar el desempeño del agente mediante la creación de un <strong>GIF animado</strong> del entorno.
# </blockquote>
#
# El GIF generado ofrece una perspectiva clara del comportamiento aprendido: cómo se mueve el agente, si toma decisiones eficientes y si logra completar el nivel o mejorar su rendimiento:

# %%
import imageio
import time
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

env = create_mario_env(WORLD, STAGE, ACTION_TYPE, n_frames_stack=N_FRAMES_STACK, render_mode="rgb_array")
env = DummyVecEnv([lambda: env])

model = PPO.load("mario_final_model")

frames = []
N_EVAL_EPISODES = 1
MAX_STEPS = 600

for ep in range(N_EVAL_EPISODES):
    obs = env.reset()
    done = [False]
    steps = 0

    while not done[0] and steps < MAX_STEPS:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        frame = env.render(mode="rgb_array")
        frames.append(frame)
        time.sleep(0.02)
        steps += 1

env.close()
imageio.mimsave("mario_agent.gif", frames, fps=30, loop=0)
print("GIF guardado como 'mario_agent.gif'")
# Out:
# c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\PracticaRLMario\.venv\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\PracticaRLMario\.venv\lib\site-packages\gym\utils\passive_env_checker.py:272: UserWarning: WARN: No render modes was declared in the environment (env.metadata['render_modes'] is None or not defined), you may have trouble when calling `.render()`.
#   logger.warn(
# GIF guardado como 'mario_agent.gif'

# %% [markdown]
# ### 4.2 Evaluación interactiva del agente (visualización en tiempo real)
#
# En esta sección se evalúa el modelo entrenado ejecutándolo directamente sobre el entorno, mostrando el resultado **en pantalla en tiempo real**.
#
# <blockquote style="border-left: 4px solid #03a9f4; background: #e8f7ff; padding: 10px; color: #333;">
# <strong>📈 Objetivo:</strong> Observar el comportamiento actual del agente mientras interactúa con el entorno, identificando patrones aprendidos, errores y decisiones clave.
# </blockquote>
#
# Esta evaluación es útil para verificar si el agente ha aprendido una estrategia coherente, así como para detectar posibles fallos o comportamientos no deseados:

# %%
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv
import time

######### EVALUACION CUANTITATIVA #########
# Creamos un nuevo entorno para evaluar el agente entrenado.
# Este entorno es el mismo que el utilizado para entrenar el agente, pero sin el vectorizado. Vigilad tambien el tipo de renderizado!
env = create_mario_env(WORLD, STAGE, ACTION_TYPE, n_frames_stack=N_FRAMES_STACK, render_mode="human")

# El entorno debe ser envuelto en un DummyVecEnv para la evaluación
env = DummyVecEnv([lambda: env])

# Cargamos el modelo entrenado
model = PPO.load("mario_final_model")

# Evaluamos el rendimiento del agente en el entorno especificado y mostramos la recompensa media y la desviación estándar.
N_EVAL_EPISODES = 10
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=N_EVAL_EPISODES, deterministic=True)

print(f"Mean reward: {mean_reward} +/- {std_reward}")

######### EVALUACION CUALITATIVA #########
# Importante! Los wrappers VecEnv devuelven solo done para el fin de estado, no trunk. 
# Del mismo modo, el reset() devuelve solo el estado y no la info.
# Tenlo en cuenta para el bucle de evaluación.

# Implementa un bucle de evaluación para analizar el rendimiento del agente entrenado de forma cualitativa.
# Consejo: añade time.sleep(0.02) tras renderizar el entorno para que la velocidad de juego sea más lenta y puedas ver mejor el rendimiento del agente.

# Reset the environment
obs = env.reset()
done = False
try:
    for e in range(N_EVAL_EPISODES):
        while not done:
            # Obtén la acción del modelo
            action, _ = model.predict(obs, deterministic=True)
            
            # Ejecuta la acción en el entorno y observa el nuevo estado, la recompensa, si ha terminado el episodio y la información adicional.
            obs, reward, done, info = env.step(action)
            
            # Renderiza el entorno para visualizar el juego
            env.render()

            # Control de la velocidad de juego
            time.sleep(0.02)
            
            if done:
                print("Episode finished. Resetting environment.")
                obs = env.reset()
                done = False
        done = False
except KeyboardInterrupt:
    print("Exiting...")
    env.close()
    exit()

# Cierra el entorno después de la evaluación
env.close()
# Out:
# c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 18
#      16 # Evaluamos el rendimiento del agente en el entorno especificado y mostramos la recompensa media y la desviación estándar.
#      17 N_EVAL_EPISODES = 10
# ---> 18 mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=N_EVAL_EPISODES, deterministic=True)
#      20 print(f"Mean reward: {mean_reward} +/- {std_reward}")
#      22 ######### EVALUACION CUALITATIVA #########
#      23 # Importante! Los wrappers VecEnv devuelven solo done para el fin de estado, no trunk.
#      24 # Del mismo modo, el reset() devuelve solo el estado y no la info.
#    (...)
#      29
#      30 # Reset the environment
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\stable_baselines3\common\evaluation.py:94, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      87 while (episode_counts < episode_count_targets).any():
#      88     actions, states = model.predict(
#      89         observations,  # type: ignore[arg-type]
#      90         state=states,
#      91         episode_start=episode_starts,
#      92         deterministic=deterministic,
#      93     )
# ---> 94     new_observations, rewards, dones, infos = env.step(actions)
#      95     current_rewards += rewards
#      96     current_lengths += 1
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# Cell In[4], line 27, in CustomStackAndRepeat.step(self, action)
#      24 info = {}
#      26 for _ in range(self.repeat):
# ---> 27     obs, reward, done, trunk, info = self.env.step(action)
#      28     processed_obs = process_frame(obs)
#      29     self.frames.append(processed_obs)
#
# Cell In[3], line 13, in CustomReward.step(self, action)
#      12 def step(self, action):
# ---> 13     obs, reward, done, trunk, info = self.env.step(action)
#      14     self.info = info
#      15     processed_img = process_frame(obs)
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\nes_py\wrappers\joypad_space.py:74, in JoypadSpace.step(self, action)
#      59 """
#      60 Take a step using the given action.
#      61
#    (...)
#      71
#      72 """
#      73 # take the step and record the output
# ---> 74 return self.env.step(self._action_map[action])
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\gym\wrappers\time_limit.py:50, in TimeLimit.step(self, action)
#      39 def step(self, action):
#      40     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      41
#      42     Args:
#    (...)
#      48
#      49     """
# ---> 50     observation, reward, terminated, truncated, info = self.env.step(action)
#      51     self._elapsed_steps += 1
#      53     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\gym\wrappers\order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\gym\wrappers\env_checker.py:39, in PassiveEnvChecker.step(self, action)
#      37     return env_step_passive_checker(self.env, action)
#      38 else:
# ---> 39     return self.env.step(action)
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\gym\wrappers\compatibility.py:108, in EnvCompatibility.step(self, action)
#     105 obs, reward, done, info = self.env.step(action)
#     107 if self.render_mode == "human":
# --> 108     self.render()
#     110 return convert_to_terminated_truncated_step_api((obs, reward, done, info))
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\gym\wrappers\compatibility.py:118, in EnvCompatibility.render(self)
#     112 def render(self) -> Any:
#     113     """Renders the environment.
#     114
#     115     Returns:
#     116         The rendering of the environment, depending on the render mode
#     117     """
# --> 118     return self.env.render(mode=self.render_mode)
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\nes_py\nes_env.py:386, in NESEnv.render(self, mode)
#     380         self.viewer = ImageViewer(
#     381             caption=caption,
#     382             height=SCREEN_HEIGHT,
#     383             width=SCREEN_WIDTH,
#     384         )
#     385     # show the screen on the image viewer
# --> 386     self.viewer.show(self.screen)
#     387 elif mode == 'rgb_array':
#     388     return self.screen
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\nes_py\_image_viewer.py:148, in ImageViewer.show(self, frame)
#     140 image = self.pyglet.image.ImageData(
#     141     frame.shape[1],
#     142     frame.shape[0],
#    (...)
#     145     pitch=frame.shape[1]*-3
#     146 )
#     147 # send the image to the window
# --> 148 image.blit(0, 0, width=self._window.width, height=self._window.height)
#     149 self._window.flip()
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\pyglet\image\__init__.py:904, in ImageData.blit(self, x, y, z, width, height)
#     903 def blit(self, x, y, z=0, width=None, height=None):
# --> 904     self.get_texture().blit(x, y, z, width, height)
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\pyglet\image\__init__.py:835, in ImageData.get_texture(self, rectangle, force_rectangle)
#     832 def get_texture(self, rectangle=False, force_rectangle=False):
#     833     if (not self._current_texture or
#     834             (not self._current_texture._is_rectangle and force_rectangle)):
# --> 835         self._current_texture = self.create_texture(Texture, rectangle, force_rectangle)
#     836     return self._current_texture
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\pyglet\image\__init__.py:821, in ImageData.create_texture(self, cls, rectangle, force_rectangle)
#     798 """Create a texture containing this image.
#     799
#     800 If the image's dimensions are not powers of 2, a TextureRegion of
#    (...)
#     818 :rtype: cls or cls.region_class
#     819 """
#     820 internalformat = self._get_internalformat(self.format)
# --> 821 texture = cls.create(self.width, self.height, internalformat,
#     822                      rectangle, force_rectangle)
#     823 if self.anchor_x or self.anchor_y:
#     824     texture.anchor_x = self.anchor_x
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\pyglet\image\__init__.py:1471, in Texture.create(cls, width, height, internalformat, rectangle, force_rectangle, min_filter, mag_filter)
#    1468 glTexParameteri(target, GL_TEXTURE_MAG_FILTER, mag_filter)
#    1470 blank = (GLubyte * (texture_width * texture_height * 4))()
# -> 1471 glTexImage2D(target, 0,
#    1472              internalformat,
#    1473              texture_width, texture_height,
#    1474              0,
#    1475              GL_RGBA, GL_UNSIGNED_BYTE,
#    1476              blank)
#    1478 texture = cls(texture_width, texture_height, target, id.value)
#    1479 texture.min_filter = min_filter
#
# File c:\Users\asahe\Desktop\UNIVERSIDAD\GIR24-25\MULTIROBOTS\DeepRL_SuperMario\.venv\lib\site-packages\pyglet\gl\lib.py:87, in errcheck(result, func, arguments)
#      83 class GLException(Exception):
#      84     pass
# ---> 87 def errcheck(result, func, arguments):
#      88     if _debug_gl_trace:
#      89         try:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
